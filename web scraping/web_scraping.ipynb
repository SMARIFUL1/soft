# %%
from bs4 import BeautifulSoup
import requests as re
import pandas as pd

# %%
url = 'https://en.wikipedia.org/wiki/List_of_largest_German_companies'
page = re.get(url)
soup=BeautifulSoup(page.text, 'html')

# %%
#print(soup)

# %%
table=soup.find_all('table')[0]

# %%
titles = table.find_all('th')

# %%
print(titles)
# Out:
# [<th>Rank
# </th>, <th>Fortune 500<br/>rank
# </th>, <th>Name
# </th>, <th>Industry
# </th>, <th>Revenue<br/><small>(USD millions)</small>
# </th>, <th>Profits<br/><small>(USD millions)</small>
# </th>, <th>Employees
# </th>, <th>Headquarters
# </th>]

# %%
table_titles=[title.text.strip() for title in titles]
print(table_titles)
# Out:
# ['Rank', 'Fortune 500rank', 'Name', 'Industry', 'Revenue(USD millions)', 'Profits(USD millions)', 'Employees', 'Headquarters']

# %%
df = pd.DataFrame(columns = table_titles)
df
# Out:
# Empty DataFrame
# Columns: [Rank, Fortune 500rank, Name, Industry, Revenue(USD millions), Profits(USD millions), Employees, Headquarters]
# Index: []

# %%
column_data = table.find_all('tr')

# %%
for row in column_data[1:]:
    row_data=row.find_all('td') #td = each row data
    each_row_data = [data.text.strip() for data in row_data]
    print(each_row_data)

    length=len(df)
    df.loc[length] = each_row_data
# Out:
# ['1', '11', 'Volkswagen', 'Automotive', '348,409', '17,945', '684,025', 'Wolfsburg']
# ['2', '41', 'BMW', 'Automotive', '168,103', '12,205', '154,950', 'Munich']
# ['3', '42', 'Mercedes-Benz Group', 'Automotive', '165,638', '15,417', '166,056', 'Stuttgart']
# ['4', '77', 'Deutsche Telekom', 'Telecommunications', '121,046', '19,239', '199,652', 'Bonn']
# ['5', '79', 'Uniper', 'Electric utility', '116,663', '6,819', '6,863', 'Düsseldorf']
# ['6', '82', 'Allianz', 'Insurance', '113,518', '9,233', '157,883', 'Munich']
# ['7', '101', 'E.ON', 'Electric utility', '101,280', '559', '72,242', 'Essen']
# ['8', '105', 'Robert Bosch GmbH', 'Automotive parts', '99,021', '2,271', '429,416', 'Stuttgart']
# ['9', '103', 'DHL Group', 'Transportation', '88,386', '3,975', '551,233', 'Bonn']
# ['10', '145', 'Siemens', 'Conglomerate', '82,932', '8,477', '320,000', 'Munich / Berlin']
# ['11', '172', 'BASF', 'Chemicals', '74,487', '243', '111,991', 'Ludwigshafen']
# ...

# %%
df
# Out:
#    Rank Fortune 500rank                          Name            Industry  \
# 0     1              11                    Volkswagen          Automotive
# 1     2              41                           BMW          Automotive
# 2     3              42           Mercedes-Benz Group          Automotive
# 3     4              77              Deutsche Telekom  Telecommunications
# 4     5              79                        Uniper    Electric utility
# 5     6              82                       Allianz           Insurance
# 6     7             101                          E.ON    Electric utility
# 7     8             105             Robert Bosch GmbH    Automotive parts
# 8     9             103                     DHL Group      Transportation
# 9    10             145                       Siemens        Conglomerate
# 10   11             172                          BASF           Chemicals
# 11   12             205                 Deutsche Bank             Banking
# ...

# %%
df.to_csv(r'C:\Users\Public\Downloads.csv', index = False)

# %% [markdown]
# ### Thanks
